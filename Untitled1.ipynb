# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_test= pd.read_csv('test.csv')

# %%
df_train = pd.read_csv('train.csv')

# %%
df_train
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df_test.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  2.335990e+05  233599.000000   233599.000000       233599.000000
# mean   1.003029e+06       8.085407        0.410070            5.276542
# std    1.726505e+03       6.521146        0.491847            3.736380
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001527e+06       2.000000        0.000000            1.000000
# 50%    1.003070e+06       7.000000        0.000000            5.000000
# 75%    1.004477e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           18.000000
#
#        Product_Category_2  Product_Category_3
# count       161255.000000        71037.000000
# mean             9.849586           12.669454
# std              5.094943            4.125944
# min              2.000000            3.000000
# 25%              5.000000            9.000000
# 50%              9.000000           14.000000
# ...

# %%
df_test.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2             72344
# Product_Category_3            162562
# dtype: int64

# %%
df_train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df_train.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
sns.heatmap(df_train.isnull(),yticklabels=False,cbar=True,cmap='viridis',)
# Out:
# <Axes: >

# %%
df = pd.concat([df_train, df_test], ignore_index=True)
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 783662  1006036  P00118942      F  26-35          15             B
# 783663  1006036  P00254642      F  26-35          15             B
# 783664  1006036  P00031842      F  26-35          15             B
# 783665  1006037  P00124742      F  46-50           1             C
# 783666  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            245982
# Product_Category_3            545809
# Purchase                      233599
# dtype: int64

# %%
df.drop(["User_ID"],axis= 1)
# Out:
#        Product_ID Gender    Age  Occupation City_Category  \
# 0       P00069042      F   0-17          10             A
# 1       P00248942      F   0-17          10             A
# 2       P00087842      F   0-17          10             A
# 3       P00085442      F   0-17          10             A
# 4       P00285442      M    55+          16             C
# ...           ...    ...    ...         ...           ...
# 783662  P00118942      F  26-35          15             B
# 783663  P00254642      F  26-35          15             B
# 783664  P00031842      F  26-35          15             B
# 783665  P00124742      F  46-50           1             C
# 783666  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# ...

# %%
sns.heatmap(df.isnull(),yticklabels=False)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# ...

# %%
pd.get_dummies(df['Gender'])
# Out:
#             F      M
# 0        True  False
# 1        True  False
# 2        True  False
# 3        True  False
# 4       False   True
# ...       ...    ...
# 783662   True  False
# 783663   True  False
# 783664   True  False
# 783665   True  False
# 783666   True  False
#
# [783667 rows x 2 columns]

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df['Gender']=df['Gender'].map({'F':0,'M':1})
df.head()
# Out:
#    User_ID Product_ID  Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042       0  0-17          10             A
# 1  1000001  P00248942       0  0-17          10             A
# 2  1000001  P00087842       0  0-17          10             A
# 3  1000001  P00085442       0  0-17          10             A
# 4  1000002  P00285442       1   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# ...

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df['Age']=df['Age'].map({'0-17':1,'55+':7,'26-35':3,'18-25':2,'36-45':4,'46-50':5,'51-55':6})

# %%
df.head()
# Out:
#    User_ID Product_ID  Gender  Age  Occupation City_Category  \
# 0  1000001  P00069042       0    1          10             A
# 1  1000001  P00248942       0    1          10             A
# 2  1000001  P00087842       0    1          10             A
# 3  1000001  P00085442       0    1          10             A
# 4  1000002  P00285442       1    7          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# ...

# %%
df_city=pd.get_dummies(df['City_Category'],drop_first=True)

# %%
df_city.head()
# Out:
#        B      C
# 0  False  False
# 1  False  False
# 2  False  False
# 3  False  False
# 4  False   True

# %%
df=pd.concat([df,df_city],axis=1)
df.head()
# Out:
#    User_ID Product_ID  Gender  Age  Occupation City_Category  \
# 0  1000001  P00069042       0    1          10             A
# 1  1000001  P00248942       0    1          10             A
# 2  1000001  P00087842       0    1          10             A
# 3  1000001  P00085442       0    1          10             A
# 4  1000002  P00285442       1    7          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase      B      C
# 0                 NaN                 NaN    8370.0  False  False
# 1                 6.0                14.0   15200.0  False  False
# ...

# %%
df.drop('City_Category',axis=1,inplace=True)

# %%
df
# Out:
#         User_ID Product_ID  Gender  Age  Occupation  \
# 0       1000001  P00069042       0    1          10
# 1       1000001  P00248942       0    1          10
# 2       1000001  P00087842       0    1          10
# 3       1000001  P00085442       0    1          10
# 4       1000002  P00285442       1    7          16
# ...         ...        ...     ...  ...         ...
# 783662  1006036  P00118942       0    3          15
# 783663  1006036  P00254642       0    3          15
# 783664  1006036  P00031842       0    3          15
# 783665  1006037  P00124742       0    5           1
# 783666  1006039  P00316642       0    5           0
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# ...

# %%
#missing values in data

df['Product_Category_2'].unique()
# Out:
# array([nan,  6., 14.,  2.,  8., 15., 16., 11.,  5.,  3.,  4., 12.,  9.,
#        10., 17., 13.,  7., 18.])

# %%
df['Product_Category_2'].value_counts()
# Out:
# Product_Category_2
# 8.0     91317
# 14.0    78834
# 2.0     70498
# 16.0    61687
# 15.0    54114
# 5.0     37165
# 4.0     36705
# 6.0     23575
# 11.0    20230
# 17.0    19104
# 13.0    15054
# 9.0      8177
# 12.0     7801
# 10.0     4420
# 3.0      4123
# 18.0     4027
# 7.0       854
# Name: count, dtype: int64

# %%
df['Product_Category_3']=df['Product_Category_3'].fillna(df['Product_Category_3'].mode()[0])

# %%
df.Product_Category_3.isnull().sum()
# Out:
# np.int64(0)

# %%
df['Product_Category_2']=df['Product_Category_2'].fillna(df['Product_Category_3'].mode()[0])

# %%
df.Product_Category_3.isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2                 0
# Product_Category_3                 0
# Purchase                      233599
# B                                  0
# C                                  0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783667 entries, 0 to 783666
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     783667 non-null  int64
#  1   Product_ID                  783667 non-null  object
#  2   Gender                      783667 non-null  int64
#  3   Age                         783667 non-null  int64
#  4   Occupation                  783667 non-null  int64
#  5   Stay_In_Current_City_Years  783667 non-null  object
#  6   Marital_Status              783667 non-null  int64
#  7   Product_Category_1          783667 non-null  int64
#  8   Product_Category_2          783667 non-null  float64
#  9   Product_Category_3          783667 non-null  float64
#  10  Purchase                    550068 non-null  float64
#  11  B                           783667 non-null  bool
#  12  C                           783667 non-null  bool
# ...

# %%
df['Stay_In_Current_City_Years']=df['Stay_In_Current_City_Years'].str.replace('+',' ')

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4 ', '3', '1', '0'], dtype=object)

# %%
df['Stay_In_Current_City_Years']=df['Stay_In_Current_City_Years'].astype(int)
df['Gender']=df['Gender'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783667 entries, 0 to 783666
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     783667 non-null  int64
#  1   Product_ID                  783667 non-null  object
#  2   Gender                      783667 non-null  int64
#  3   Age                         783667 non-null  int64
#  4   Occupation                  783667 non-null  int64
#  5   Stay_In_Current_City_Years  783667 non-null  int64
#  6   Marital_Status              783667 non-null  int64
#  7   Product_Category_1          783667 non-null  int64
#  8   Product_Category_2          783667 non-null  float64
#  9   Product_Category_3          783667 non-null  float64
#  10  Purchase                    550068 non-null  float64
#  11  B                           783667 non-null  bool
#  12  C                           783667 non-null  bool
# ...

# %%
df['B']=df['B'].astype(int)
df['C']=df['C'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783667 entries, 0 to 783666
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     783667 non-null  int64
#  1   Product_ID                  783667 non-null  object
#  2   Gender                      783667 non-null  int64
#  3   Age                         783667 non-null  int64
#  4   Occupation                  783667 non-null  int64
#  5   Stay_In_Current_City_Years  783667 non-null  int64
#  6   Marital_Status              783667 non-null  int64
#  7   Product_Category_1          783667 non-null  int64
#  8   Product_Category_2          783667 non-null  float64
#  9   Product_Category_3          783667 non-null  float64
#  10  Purchase                    550068 non-null  float64
#  11  B                           783667 non-null  int64
#  12  C                           783667 non-null  int64
# ...

# %%
#lets se which age and gender has more purchase power

sns.barplot(x='Age',y='Purchase',hue='Gender',data= df)
# Out:
# <Axes: xlabel='Age', ylabel='Purchase'>

# %% [markdown]
# ## Business analisis
# we can clearly se that we have more female custumers from various age groups so we should come up with more sale and offers for female custumers but we cant really eggnore male custumers as they are also in a siggnificant high amount

# %%
sns.barplot(x='Product_Category_1',y= 'Purchase',hue='Gender',data= df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='Purchase'>

# %%
plt.figure(figsize=(9,9))
sns.barplot(x='Product_Category_2',y= 'Purchase',hue='Gender',data= df)
# Out:
# <Axes: xlabel='Product_Category_2', ylabel='Purchase'>

# %%
 sns.barplot(x='Product_Category_3',y='Purchase',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Product_Category_3', ylabel='Purchase'>

# %%
##Feature Scaling 
df_test=df[df['Purchase'].isnull()]

# %%
df_train = df[~df['Purchase'].isnull()]

# %%
df_train.Purchase.isnull().sum()
# Out:
# np.int64(0)

# %%
x= df_train.drop(['Purchase', 'User_ID', 'Product_ID'],axis=1)

# %%
y = df_train['Purchase']
y
# Out:
# 0          8370.0
# 1         15200.0
# 2          1422.0
# 3          1057.0
# 4          7969.0
#            ...
# 550063      368.0
# 550064      371.0
# 550065      137.0
# 550066      365.0
# 550067      490.0
# Name: Purchase, Length: 550068, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
     x, y, test_size=0.33, random_state=42)

# %%
X_train.isnull().sum()
# Out:
# Gender                        0
# Age                           0
# Occupation                    0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# B                             0
# C                             0
# dtype: int64

# %% [raw]
# X_train.drop('Product_ID',axis=1,inplace=True)
# X_test.drop('Product_ID',axis=1,inplace=True)

# %%
X_train
# Out:
#         Gender  Age  Occupation  Stay_In_Current_City_Years  Marital_Status  \
# 396876       1    2          14                           3               0
# 433826       1    6           0                           0               1
# 516298       1    4          17                           0               0
# 193380       1    3           4                           1               0
# 273542       0    4          20                           3               1
# ...        ...  ...         ...                         ...             ...
# 110268       1    5          17                           2               0
# 259178       1    3          14                           2               1
# 365838       0    2           1                           1               0
# 131932       0    2           4                           2               0
# 121958       0    2           2                           2               1
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
#sc = StandardScaler()
#X_train=sc.fit_transform(X_train)
#X_test=sc.transform(X_test)

# %%
X_train.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13316\1519562538.py in ?()
# ----> 1 X_train.dtype
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline

# %%
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('model', LinearRegression())
])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('model', LinearRegression())])

# %%
y_pred = pipeline.predict(X_test)

# %%
pd.DataFrame({
    'Actual': y_test,
    'Predicted': y_pred
}).tail()
# Out:
#          Actual     Predicted
# 196106   9787.0   7816.509794
# 109474   3198.0   6939.766365
# 433228   5434.0  11075.786253
# 271831  19051.0  12422.916101
# 477613  11896.0  10039.334053

# %%
plt.scatter(y_test, y_pred)

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)

# %%
mae
# Out:
# 3561.266328270291

# %%
baseline_pred = [y_train.mean()] * len(y_test)
baseline_mae = mean_absolute_error(y_test, baseline_pred)
baseline_mae
# Out:
# 4064.889289833162

# %%
a = baseline_mae-mae
a= a/baseline_mae
a*100
# Out:
# 12.38958617698396

# %%
from sklearn.ensemble import RandomForestRegressor
upd1_pipeline = Pipeline([
    
    ('model', RandomForestRegressor(
        n_estimators=200,
        random_state=42,
        n_jobs=-1
    ))
])

# %%
upd1_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('model',
#                  RandomForestRegressor(n_estimators=200, n_jobs=-1,
#                                        random_state=42))])

# %%
y_pred_upd1 = upd1_pipeline.predict(X_test)

# %%
pd.DataFrame({
    'Actual': y_test,
    'Predicted': y_pred_upd1
}).head()
# Out:
#          Actual     Predicted
# 84432   19142.0  13383.234750
# 72724   15513.0  14579.097353
# 197032   7802.0   7689.889446
# 353704  15455.0  13794.212190
# 91198    4492.0  15432.903153

# %%
plt.scatter(y_test, y_pred_upd1)

# %%
mae_1 = mean_absolute_error(y_test, y_pred_upd1)
mae_1
# Out:
# 2224.8054517970154

# %%
a = baseline_mae-mae_1
a= a/baseline_mae
a*100
# Out:
# 45.26774794675085

# %%
plt.scatter(y_test, y_pred, alpha=0.3)
plt.plot([y_test.min(), y_test.max()],
         [y_test.min(), y_test.max()])
plt.xlabel("Actual Purchase")
plt.ylabel("Predicted Purchase")
plt.show()

# %%
# !pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from xgboost import XGBRegressor

xgb = XGBRegressor(
    n_estimators=600,
    learning_rate=0.05,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    objective='reg:squarederror',
    random_state=42
)

#xgb.fit(X_train, y_train)
#3y_pred_1 = xgb.predict(X_test)

# %%
y_train_log = np.log1p(y_train)
y_test_log  = np.log1p(y_test)

xgb.fit(X_train, y_train_log)
y_pred_2 = np.expm1(xgb.predict(X_test))

mae = mean_absolute_error(y_test, y_pred)
print(mae)
# Out:
# 2174.5160499749954

# %%
pd.DataFrame({
    'Actual': y_test,
    'Predicted': y_pred_1
}).head()
# Out:
#          Actual     Predicted
# 84432   19142.0  15147.083008
# 72724   15513.0  13480.309570
# 197032   7802.0   7170.375488
# 353704  15455.0  13282.964844
# 91198    4492.0  16177.295898

# %%
plt.scatter(y_test, y_pred_1)

# %%
plt.scatter(y_test, y_pred_1, alpha=0.3)
plt.plot([y_test.min(), y_test.max()],
         [y_test.min(), y_test.max()])
plt.xlabel("Actual Purchase")
plt.ylabel("Predicted Purchase")
plt.show()

# %%
mae_1 = mean_absolute_error(y_test, y_pred_1)
mae_1
# Out:
# 2174.5160499749954

# %%
y_train_log = np.log1p(y_train)
y_test_log  = np.log1p(y_test)

xgb.fit(X_train, y_train_log)
y_pred_2 = np.expm1(xgb.predict(X_test))

mae = mean_absolute_error(y_test, y_pred)
print(mae)
# Out:
# 2174.5160499749954

# %%
plt.scatter(y_test, y_pred_2, alpha=0.3)
plt.plot([y_test.min(), y_test.max()],
         [y_test.min(), y_test.max()])
plt.xlabel("Actual Purchase")
plt.ylabel("Predicted Purchase")
plt.show()

# %%
from catboost import CatBoostRegressor

cat = CatBoostRegressor(
    depth=8,
    learning_rate=0.05,
    iterations=500,
    loss_function='MAE',
    verbose=0
)

cat.fit(X_train, y_train)
y_pred_3 = cat.predict(X_test)

# %%
pd.DataFrame({
    'Actual': y_test,
    'Predicted': y_pred_3
}).head()
# Out:
#          Actual     Predicted
# 84432   19142.0  15508.205213
# 72724   15513.0  14855.843669
# 197032   7802.0   7877.299593
# 353704  15455.0  14311.729299
# 91198    4492.0  16347.974881

# %%
mae_3 = mean_absolute_error(y_test, y_pred_3)
mae_3
# Out:
# 2147.242291369802

# %%
plt.scatter(y_test, y_pred_3, alpha=0.3)
plt.plot([y_test.min(), y_test.max()],
         [y_test.min(), y_test.max()])
plt.xlabel("Actual Purchase")
plt.ylabel("Predicted Purchase")
plt.show()

# %%
cat.save_model("catboost_model.cbm")
